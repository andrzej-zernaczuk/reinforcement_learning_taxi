# %% [markdown]
# # PPO Training for Taxi-v3 (Baseline)
#
# This notebook trains a PPO agent using **baseline hyperparameters** (before tuning).
#
# **Note**: For optimized hyperparameters, see notebook `05_ppo_training_optimized.ipynb` (run after hyperparameter tuning).

# %%
import sys

sys.path.append('..')

from pathlib import Path

import gymnasium as gym
import imageio
import numpy as np
import yaml

from reinforcement_learning_taxi.agents.ppo_agent import PPOAgent
from reinforcement_learning_taxi.environments import TaxiActionMaskWrapper, TaxiFeatureWrapper, make_taxi_env
from reinforcement_learning_taxi.evaluation.metrics import evaluate_agent
from reinforcement_learning_taxi.training.ppo_trainer import PPOTrainer
from reinforcement_learning_taxi.visualization.training_plots import plot_episode_length, plot_learning_curve

# %% [markdown]
# ## Load Configuration

# %%
with open('../src/reinforcement_learning_taxi/configs/ppo_config_baseline.yaml', 'r') as f:
    config = yaml.safe_load(f)

print("Configuration loaded:")
print(f"  Environment: {config['environment']['name']}")
print(f"  Training timesteps: {config['training']['total_timesteps']}")
print(f"  Policy: {config['agent']['policy']}")
print(f"  Learning rate: {config['agent']['learning_rate']}")
print(f"  N steps: {config['agent']['n_steps']}")
print(f"  Batch size: {config['agent']['batch_size']}")
print(f"  Seed: {config['agent']['seed']}")
# Out:
# Configuration loaded:
#   Environment: Taxi-v3
#   Training timesteps: 200000
#   Policy: MlpPolicy
#   Learning rate: 0.0003
#   N steps: 1024
#   Batch size: 64
#   Seed: 42

# %% [markdown]
# ## Initialize Environment and Agent

# %%
# Create environment with feature wrapper for proper observation encoding
env = make_taxi_env(
    render_mode=config['environment'].get('render_mode'),
    use_feature_wrapper=True,  # Converts discrete obs to 19-dim feature vector
    use_action_masking=True,  # Enable valid-action masking for PPO
)

print(f"Environment observation space: {env.observation_space}")
print(f"Environment action space: {env.action_space}")

agent = PPOAgent(
    env=env,
    policy=config['agent']['policy'],
    learning_rate=config['agent']['learning_rate'],
    n_steps=config['agent']['n_steps'],
    batch_size=config['agent']['batch_size'],
    n_epochs=config['agent']['n_epochs'],
    gamma=config['agent']['gamma'],
    gae_lambda=config['agent']['gae_lambda'],
    clip_range=config['agent']['clip_range'],
    clip_range_vf=config['agent']['clip_range_vf'],
    ent_coef=config['agent']['ent_coef'],
    vf_coef=config['agent']['vf_coef'],
    max_grad_norm=config['agent']['max_grad_norm'],
    policy_kwargs=config['agent']['policy_kwargs'],
    verbose=config['agent']['verbose'],
    seed=config['agent']['seed'],
    use_action_masking=True,
)

print("PPO agent initialized with stable-baselines3")
# Out:
# Environment observation space: Box(0.0, 1.0, (19,), float32)
# Environment action space: Discrete(6)
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# PPO agent initialized with stable-baselines3

# %% [markdown]
# ## Train Agent

# %%
trainer = PPOTrainer(
    env=env,
    agent=agent,
    log_dir=config['training']['log_dir'],
    checkpoint_freq=config['training']['checkpoint_freq'],
    eval_freq=config['training']['eval_freq'],
    eval_episodes=config['training']['eval_episodes'],
)

print("Starting training...")
stats = trainer.train(total_timesteps=config['training']['total_timesteps'])

print("\nTraining completed!")
print(f"  Total timesteps: {stats['total_timesteps']}")
print(f"  Training time: {stats['training_time']:.2f} seconds")
print(f"  Episodes completed: {len(stats['episode_rewards'])}")
# Out:
# Starting training...
# Eval num_timesteps=5000, episode_reward=-200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | -200         |
# | time/                   |              |
# |    total_timesteps      | 5000         |
# | train/                  |              |
# |    approx_kl            | 0.0050424878 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.978       |
# |    explained_variance   | 0.0822       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.9         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00537     |
# |    value_loss           | 68.6         |
# ------------------------------------------
# New best mean reward!
# Eval num_timesteps=10000, episode_reward=-200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | -200         |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0021904516 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.9         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00533     |
# |    value_loss           | 88           |
# ------------------------------------------
# Eval num_timesteps=15000, episode_reward=-200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | -200         |
# | time/                   |              |
# |    total_timesteps      | 15000        |
# | train/                  |              |
# |    approx_kl            | 0.0069871377 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.0136       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.8         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 80.2         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=-200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | -200        |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.004990512 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.5        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 29.7        |
# -----------------------------------------
# Eval num_timesteps=25000, episode_reward=-200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | -200         |
# | time/                   |              |
# |    total_timesteps      | 25000        |
# | train/                  |              |
# |    approx_kl            | 0.0022798944 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.596       |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.16         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 77.3         |
# ------------------------------------------
# Eval num_timesteps=30000, episode_reward=-193.71 +/- 35.77
# Episode length: 194.34 +/- 32.19
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 194          |
# |    mean_reward          | -194         |
# | time/                   |              |
# |    total_timesteps      | 30000        |
# | train/                  |              |
# |    approx_kl            | 0.0028909082 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | 0.868        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.6         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0052      |
# |    value_loss           | 85.4         |
# ------------------------------------------
# New best mean reward!
# Eval num_timesteps=35000, episode_reward=-187.49 +/- 49.52
# Episode length: 188.75 +/- 44.54
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 189        |
# |    mean_reward          | -187       |
# | time/                   |            |
# |    total_timesteps      | 35000      |
# | train/                  |            |
# |    approx_kl            | 0.00480627 |
# |    clip_fraction        | 0.0179     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.471     |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.62       |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.00631   |
# |    value_loss           | 23.3       |
# ----------------------------------------
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=-197.94 +/- 20.50
# Episode length: 198.15 +/- 18.41
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 198          |
# |    mean_reward          | -198         |
# | time/                   |              |
# |    total_timesteps      | 40000        |
# | train/                  |              |
# |    approx_kl            | 0.0024190345 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.576       |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.6         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00455     |
# |    value_loss           | 57.4         |
# ------------------------------------------
# Eval num_timesteps=45000, episode_reward=-200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | -200        |
# | time/                   |             |
# |    total_timesteps      | 45000       |
# | train/                  |             |
# |    approx_kl            | 0.009783465 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.438      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.257       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00486    |
# |    value_loss           | 6.18        |
# -----------------------------------------
# Eval num_timesteps=50000, episode_reward=-200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | -200        |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 0.060141258 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0266      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 0.328       |
# -----------------------------------------
# Eval num_timesteps=55000, episode_reward=-164.31 +/- 78.87
# Episode length: 167.88 +/- 70.98
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 168          |
# |    mean_reward          | -164         |
# | time/                   |              |
# |    total_timesteps      | 55000        |
# | train/                  |              |
# |    approx_kl            | 0.0042400034 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.652       |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00875     |
# |    value_loss           | 42.8         |
# ------------------------------------------
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=-172.63 +/- 70.81
# Episode length: 175.36 +/- 63.75
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 175        |
# |    mean_reward          | -173       |
# | time/                   |            |
# |    total_timesteps      | 60000      |
# | train/                  |            |
# |    approx_kl            | 0.01667859 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.723     |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.94       |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0161    |
# |    value_loss           | 22.4       |
# ----------------------------------------
# Eval num_timesteps=65000, episode_reward=-120.67 +/- 101.34
# Episode length: 128.65 +/- 91.15
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 129         |
# |    mean_reward          | -121        |
# | time/                   |             |
# |    total_timesteps      | 65000       |
# | train/                  |             |
# |    approx_kl            | 0.008274982 |
# |    clip_fraction        | 0.0393      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.83        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00761    |
# |    value_loss           | 12.1        |
# -----------------------------------------
# New best mean reward!
# Eval num_timesteps=70000, episode_reward=-133.10 +/- 97.53
# Episode length: 139.82 +/- 87.74
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 140       |
# |    mean_reward          | -133      |
# | time/                   |           |
# |    total_timesteps      | 70000     |
# | train/                  |           |
# |    approx_kl            | 0.0162468 |
# |    clip_fraction        | 0.12      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.545    |
# |    explained_variance   | 0.943     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.65      |
# |    n_updates            | 680       |
# |    policy_gradient_loss | -0.0103   |
# |    value_loss           | 35.5      |
# ---------------------------------------
# Eval num_timesteps=75000, episode_reward=-176.93 +/- 65.62
# Episode length: 179.24 +/- 59.05
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 179          |
# |    mean_reward          | -177         |
# | time/                   |              |
# |    total_timesteps      | 75000        |
# | train/                  |              |
# |    approx_kl            | 0.0040026866 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.11         |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 22.4         |
# ------------------------------------------
# Eval num_timesteps=80000, episode_reward=-102.15 +/- 103.93
# Episode length: 112.02 +/- 93.45
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 112         |
# |    mean_reward          | -102        |
# | time/                   |             |
# |    total_timesteps      | 80000       |
# | train/                  |             |
# |    approx_kl            | 0.008365784 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.308      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27        |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00806    |
# |    value_loss           | 9.98        |
# -----------------------------------------
# New best mean reward!
# Eval num_timesteps=85000, episode_reward=-143.85 +/- 92.34
# Episode length: 149.52 +/- 83.01
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 150         |
# |    mean_reward          | -144        |
# | time/                   |             |
# |    total_timesteps      | 85000       |
# | train/                  |             |
# |    approx_kl            | 0.006421121 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.285      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.87        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00873    |
# |    value_loss           | 17.8        |
# -----------------------------------------
# Eval num_timesteps=90000, episode_reward=-162.58 +/- 79.88
# Episode length: 166.36 +/- 71.81
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 166         |
# |    mean_reward          | -163        |
# | time/                   |             |
# |    total_timesteps      | 90000       |
# | train/                  |             |
# |    approx_kl            | 0.011309819 |
# |    clip_fraction        | 0.0421      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.317      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 47.7        |
# -----------------------------------------
# Eval num_timesteps=95000, episode_reward=-129.04 +/- 98.88
# Episode length: 136.18 +/- 88.93
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 136        |
# |    mean_reward          | -129       |
# | time/                   |            |
# |    total_timesteps      | 95000      |
# | train/                  |            |
# |    approx_kl            | 0.01741078 |
# |    clip_fraction        | 0.0771     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.249     |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.54       |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.0178    |
# |    value_loss           | 11.1       |
# ----------------------------------------
# Eval num_timesteps=100000, episode_reward=-156.80 +/- 83.79
# Episode length: 161.21 +/- 75.24
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 161          |
# |    mean_reward          | -157         |
# | time/                   |              |
# |    total_timesteps      | 100000       |
# | train/                  |              |
# |    approx_kl            | 0.0074086627 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.102       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.3          |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0176      |
# |    value_loss           | 8.05         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91          |
# |    ep_rew_mean          | -77.6       |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 100         |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.010082127 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.189      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.1        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 26.9        |
# -----------------------------------------
# Eval num_timesteps=105000, episode_reward=-156.07 +/- 85.22
# Episode length: 160.48 +/- 76.66
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 160         |
# |    mean_reward          | -156        |
# | time/                   |             |
# |    total_timesteps      | 105000      |
# | train/                  |             |
# |    approx_kl            | 0.013905641 |
# |    clip_fraction        | 0.0766      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.229      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.05        |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 4.08        |
# -----------------------------------------
# Eval num_timesteps=110000, episode_reward=-123.41 +/- 99.95
# Episode length: 131.18 +/- 89.81
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 131         |
# |    mean_reward          | -123        |
# | time/                   |             |
# |    total_timesteps      | 110000      |
# | train/                  |             |
# |    approx_kl            | 0.010877462 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.13       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.48        |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 2.17        |
# -----------------------------------------
# Eval num_timesteps=115000, episode_reward=-117.22 +/- 101.40
# Episode length: 125.62 +/- 91.11
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 126         |
# |    mean_reward          | -117        |
# | time/                   |             |
# |    total_timesteps      | 115000      |
# | train/                  |             |
# |    approx_kl            | 0.018310485 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.323      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.49        |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 8.7         |
# -----------------------------------------
# Eval num_timesteps=120000, episode_reward=-160.44 +/- 81.70
# Episode length: 164.43 +/- 73.46
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 164         |
# |    mean_reward          | -160        |
# | time/                   |             |
# |    total_timesteps      | 120000      |
# | train/                  |             |
# |    approx_kl            | 0.041851074 |
# |    clip_fraction        | 0.0645      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0667     |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12        |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 3.7         |
# -----------------------------------------
# Eval num_timesteps=125000, episode_reward=-147.54 +/- 90.88
# Episode length: 152.79 +/- 81.78
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 153         |
# |    mean_reward          | -148        |
# | time/                   |             |
# |    total_timesteps      | 125000      |
# | train/                  |             |
# |    approx_kl            | 0.008924813 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.34       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.44        |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | -0.00659    |
# |    value_loss           | 16.4        |
# -----------------------------------------
# Eval num_timesteps=130000, episode_reward=-133.26 +/- 97.30
# Episode length: 139.98 +/- 87.50
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 140         |
# |    mean_reward          | -133        |
# | time/                   |             |
# |    total_timesteps      | 130000      |
# | train/                  |             |
# |    approx_kl            | 0.006664403 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.224      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49        |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | -0.00889    |
# |    value_loss           | 14.2        |
# -----------------------------------------
# Eval num_timesteps=135000, episode_reward=-104.69 +/- 103.29
# Episode length: 114.35 +/- 92.82
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 114         |
# |    mean_reward          | -105        |
# | time/                   |             |
# |    total_timesteps      | 135000      |
# | train/                  |             |
# |    approx_kl            | 0.008590365 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.7        |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 48.1        |
# -----------------------------------------
# Eval num_timesteps=140000, episode_reward=-77.46 +/- 102.17
# Episode length: 89.85 +/- 91.84
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 89.8        |
# |    mean_reward          | -77.5       |
# | time/                   |             |
# |    total_timesteps      | 140000      |
# | train/                  |             |
# |    approx_kl            | 0.007708508 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.109      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.201       |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.00916    |
# |    value_loss           | 2.87        |
# -----------------------------------------
# New best mean reward!
# Eval num_timesteps=145000, episode_reward=-112.75 +/- 102.55
# Episode length: 121.57 +/- 92.19
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 122         |
# |    mean_reward          | -113        |
# | time/                   |             |
# |    total_timesteps      | 145000      |
# | train/                  |             |
# |    approx_kl            | 0.008341065 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.303      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 56.8        |
# -----------------------------------------
# Eval num_timesteps=150000, episode_reward=-77.50 +/- 102.14
# Episode length: 89.89 +/- 91.82
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 89.9       |
# |    mean_reward          | -77.5      |
# | time/                   |            |
# |    total_timesteps      | 150000     |
# | train/                  |            |
# |    approx_kl            | 0.02754412 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.206     |
# |    explained_variance   | 0.99       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.474      |
# |    n_updates            | 1460       |
# |    policy_gradient_loss | 0.00887    |
# |    value_loss           | 1.93       |
# ----------------------------------------
# Eval num_timesteps=155000, episode_reward=-139.92 +/- 94.02
# Episode length: 146.01 +/- 84.49
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 146         |
# |    mean_reward          | -140        |
# | time/                   |             |
# |    total_timesteps      | 155000      |
# | train/                  |             |
# |    approx_kl            | 0.009796638 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0503     |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0252     |
# |    n_updates            | 1510        |
# |    policy_gradient_loss | -0.00646    |
# |    value_loss           | 0.607       |
# -----------------------------------------
# Eval num_timesteps=160000, episode_reward=-143.67 +/- 92.63
# Episode length: 149.34 +/- 83.31
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 149         |
# |    mean_reward          | -144        |
# | time/                   |             |
# |    total_timesteps      | 160000      |
# | train/                  |             |
# |    approx_kl            | 0.011507664 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.082      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 1560        |
# |    policy_gradient_loss | 0.00131     |
# |    value_loss           | 0.13        |
# -----------------------------------------
# Eval num_timesteps=165000, episode_reward=-106.94 +/- 102.90
# Episode length: 116.39 +/- 92.46
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 116          |
# |    mean_reward          | -107         |
# | time/                   |              |
# |    total_timesteps      | 165000       |
# | train/                  |              |
# |    approx_kl            | 0.0077024186 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.185       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.8         |
# |    n_updates            | 1610         |
# |    policy_gradient_loss | -0.00947     |
# |    value_loss           | 23.7         |
# ------------------------------------------
# Eval num_timesteps=170000, episode_reward=-59.28 +/- 96.57
# Episode length: 73.56 +/- 86.78
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 73.6       |
# |    mean_reward          | -59.3      |
# | time/                   |            |
# |    total_timesteps      | 170000     |
# | train/                  |            |
# |    approx_kl            | 0.00551268 |
# |    clip_fraction        | 0.0521     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.101     |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.69       |
# |    n_updates            | 1660       |
# |    policy_gradient_loss | -0.00612   |
# |    value_loss           | 5.3        |
# ----------------------------------------
# New best mean reward!
# Eval num_timesteps=175000, episode_reward=-42.58 +/- 88.49
# Episode length: 58.54 +/- 79.53
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 58.5        |
# |    mean_reward          | -42.6       |
# | time/                   |             |
# |    total_timesteps      | 175000      |
# | train/                  |             |
# |    approx_kl            | 0.022340221 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0828     |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00476     |
# |    n_updates            | 1700        |
# |    policy_gradient_loss | -0.00963    |
# |    value_loss           | 0.348       |
# -----------------------------------------
# New best mean reward!
# Eval num_timesteps=180000, episode_reward=-63.18 +/- 98.24
# Episode length: 77.04 +/- 88.29
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 77          |
# |    mean_reward          | -63.2       |
# | time/                   |             |
# |    total_timesteps      | 180000      |
# | train/                  |             |
# |    approx_kl            | 0.011482586 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.106      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.02        |
# |    n_updates            | 1750        |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 8.23        |
# -----------------------------------------
# Eval num_timesteps=185000, episode_reward=-88.52 +/- 102.91
# Episode length: 99.86 +/- 92.44
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 99.9        |
# |    mean_reward          | -88.5       |
# | time/                   |             |
# |    total_timesteps      | 185000      |
# | train/                  |             |
# |    approx_kl            | 0.009192023 |
# |    clip_fraction        | 0.0271      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.102      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.33        |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 8.36        |
# -----------------------------------------
# Eval num_timesteps=190000, episode_reward=-50.78 +/- 93.09
# Episode length: 65.90 +/- 83.66
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 65.9       |
# |    mean_reward          | -50.8      |
# | time/                   |            |
# |    total_timesteps      | 190000     |
# | train/                  |            |
# |    approx_kl            | 0.01477719 |
# |    clip_fraction        | 0.0579     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.145     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00117   |
# |    n_updates            | 1850       |
# |    policy_gradient_loss | -0.00434   |
# |    value_loss           | 0.267      |
# ----------------------------------------
# Eval num_timesteps=195000, episode_reward=-126.87 +/- 99.67
# Episode length: 134.22 +/- 89.65
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 134        |
# |    mean_reward          | -127       |
# | time/                   |            |
# |    total_timesteps      | 195000     |
# | train/                  |            |
# |    approx_kl            | 0.04446449 |
# |    clip_fraction        | 0.048      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0874    |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0526     |
# |    n_updates            | 1900       |
# |    policy_gradient_loss | -0.0105    |
# |    value_loss           | 0.219      |
# ----------------------------------------
# Eval num_timesteps=200000, episode_reward=-93.50 +/- 104.41
# Episode length: 104.21 +/- 93.91
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 104        |
# |    mean_reward          | -93.5      |
# | time/                   |            |
# |    total_timesteps      | 200000     |
# | train/                  |            |
# |    approx_kl            | 0.01772179 |
# |    clip_fraction        | 0.0921     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.337     |
# |    explained_variance   | 0.978      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.895      |
# |    n_updates            | 1950       |
# |    policy_gradient_loss | -0.00587   |
# |    value_loss           | 8.04       |
# ----------------------------------------
#
# Training completed!
#   Total timesteps: 200000
#   Training time: 199.89 seconds
#   Episodes completed: 2103

# %% [markdown]
# ## Visualize Training Progress

# %%
plot_dir = Path(config['training']['log_dir']) / 'plots'
plot_dir.mkdir(parents=True, exist_ok=True)

if stats['episode_rewards']:
    plot_learning_curve(
        stats['episode_rewards'],
        title="PPO Training Progress: Reward",
        save_path=plot_dir / "learning_curve.png",
    )

    plot_episode_length(
        stats['episode_lengths'],
        title="PPO Training Progress: Episode Length",
        save_path=plot_dir / "episode_length.png",
    )

    print(f"Training plots saved to {plot_dir}")
else:
    print("No episode data available for plotting")
# Out:
# Training plots saved to ../results/logs/ppo_baseline/plots

# %% [markdown]
# ## Evaluate Trained Agent

# %%
eval_results = evaluate_agent(
    agent=agent,
    env=env,
    n_episodes=config['evaluation']['n_episodes'],
    deterministic=config['evaluation']['deterministic'],
)

print("Evaluation Results:")
print(f"  Mean reward: {eval_results['mean_reward']:.2f} ± {eval_results['std_reward']:.2f}")
print(f"  Success rate: {eval_results['success_rate']:.2%}")
print(f"  Mean episode length: {eval_results['mean_length']:.2f}")
print(f"  Reward range: [{eval_results['min_reward']:.2f}, {eval_results['max_reward']:.2f}]")
# Out:
# Evaluation Results:
#   Mean reward: -98.27 ± 103.61
#   Success rate: 46.60%
#   Mean episode length: 108.58
#   Reward range: [-200.00, 15.00]

# %% [markdown]
# ## Test on Sample Episode

# %%
# Save 10 episodes into one video
render_dir = Path('../results/renders')
render_dir.mkdir(parents=True, exist_ok=True)

env_render = gym.make(config['environment']['name'], render_mode='rgb_array')
env_render = TaxiFeatureWrapper(env_render)
env_render = TaxiActionMaskWrapper(env_render)

video_path = render_dir / 'ppo_baseline_10runs.mp4'
fps = 10
pause_frames = fps

seeds = [999 + i for i in range(10)]
episode_stats = []

with imageio.get_writer(video_path, fps=fps) as writer:
    for i, seed in enumerate(seeds, start=1):
        state, _ = env_render.reset(seed=seed)
        frame = env_render.render()
        writer.append_data(frame)
        done = False
        steps = 0
        ep_reward = 0
        while not done and steps < 200:
            action, _ = agent.predict(
                state,
                deterministic=True,
                action_masks=env_render.action_masks(),
            )
            if isinstance(action, np.ndarray):
                action = int(action.item())
            state, reward, terminated, truncated, _ = env_render.step(action)
            frame = env_render.render()
            writer.append_data(frame)
            done = terminated or truncated
            ep_reward += reward
            steps += 1
        success = ep_reward > 0
        episode_stats.append((steps, ep_reward, success))
        print(f'Episode {i}: steps={steps}, reward={ep_reward}, success={success}')
        if i != len(seeds):
            for _ in range(pause_frames):
                writer.append_data(frame)

env_render.close()
mean_reward = sum(r for _s, r, _su in episode_stats) / len(episode_stats)
mean_steps = sum(s for s, _r, _su in episode_stats) / len(episode_stats)
success_rate = sum(1 for _s, _r, su in episode_stats if su) / len(episode_stats)
print(f'Video saved to {video_path}')
print(f'Summary: mean_reward={mean_reward:.2f}, mean_steps={mean_steps:.2f}, success_rate={success_rate:.2%}')
# Out:
# /Users/azernaczuk/Documents/0sobiste/github/reinforcement_learning_taxi/.venv/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (550, 350) to (560, 352) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Episode 1: steps=10, reward=11, success=True
# Episode 2: steps=15, reward=6, success=True
# Episode 3: steps=200, reward=-200, success=False
# Episode 4: steps=13, reward=8, success=True
# Episode 5: steps=200, reward=-200, success=False
# Episode 6: steps=10, reward=11, success=True
# Episode 7: steps=20, reward=1, success=True
# Episode 8: steps=9, reward=12, success=True
# Episode 9: steps=200, reward=-200, success=False
# Episode 10: steps=200, reward=-200, success=False
# Video saved to ../results/renders/ppo_baseline_10runs.mp4
# Summary: mean_reward=-75.10, mean_steps=87.70, success_rate=60.00%
